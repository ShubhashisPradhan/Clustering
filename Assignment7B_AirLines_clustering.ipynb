# %% [markdown]
# # Hierarchical

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
#pip install xlrd

# %%
data_air=pd.read_excel("/content/sample_data/EastWestAirlines.xlsx", sheet_name="data")
data_air.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
#EDA
data_air.rename({'ID#':'ID','Award?':'Award'},axis=1,inplace=True)
data_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data_air.describe().T
# Out:
#                     count          mean            std  min      25%      50%  \
# ID                 3999.0   2014.819455    1160.764358  1.0   1010.5   2016.0
# Balance            3999.0  73601.327582  100775.664958  0.0  18527.5  43097.0
# Qual_miles         3999.0    144.114529     773.663804  0.0      0.0      0.0
# cc1_miles          3999.0      2.059515       1.376919  1.0      1.0      1.0
# cc2_miles          3999.0      1.014504       0.147650  1.0      1.0      1.0
# cc3_miles          3999.0      1.012253       0.195241  1.0      1.0      1.0
# Bonus_miles        3999.0  17144.846212   24150.967826  0.0   1250.0   7171.0
# Bonus_trans        3999.0     11.601900       9.603810  0.0      3.0     12.0
# Flight_miles_12mo  3999.0    460.055764    1400.209171  0.0      0.0      0.0
# Flight_trans_12    3999.0      1.373593       3.793172  0.0      0.0      0.0
# Days_since_enroll  3999.0   4118.559390    2065.134540  2.0   2330.0   4096.0
# ...

# %%
#null value
data_air.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
#duplicated
data_air[data_air.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award]
# Index: []

# %%
#lets check for outliers
data_air1=data_air.drop(['ID'],axis=1)
data_air1.boxplot()
# Out:
# <Axes: >

# %%
# correlation heatmap

f,ax = plt.subplots(figsize=(18,12))
sns.heatmap(data_air1.corr(), annot=True, linewidths =.5, fmt ='.1f',ax=ax)
plt.show()

# %%
def norm_fun(val):
  return (val-val.min())/(val.max()-val.min())

# %%
air_norm=norm_fun(data_air1)
air_norm.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0     0.011628           0.000000         0.000000           0.843742    0.0
# 1     0.023256           0.000000         0.000000           0.839884    0.0
# 2     0.046512           0.000000         0.000000           0.847842    0.0
# 3     0.011628           0.000000         0.000000           0.837955    0.0
# 4     0.302326           0.067398         0.075472           0.835905    1.0

# %%
#lets start hierarchical clustering
plt.figure(figsize=(10, 7))
dendogram=sch.dendrogram(sch.linkage(air_norm,method='average'))

# %%
#agglomerative clustering
hc=AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='average')
y_hc=hc.fit_predict(air_norm)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
air_norm['clusterId']=y_hc
air_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data_air1['clusterId']=y_hc
data_air1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_clust=data_air1.groupby('clusterId').mean()
df_clust
# Out:
#                 Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterId
# 0          9.586906e+04  240.069783   2.663279   1.015583   1.018293
# 1          5.980784e+04   87.602462   1.705322   1.013900   1.008737
# 2          1.704838e+06    0.000000   1.000000   1.000000   1.000000
# 3          1.319995e+05  347.000000   2.500000   1.000000   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterId
# 0          28813.871274    15.626694         803.046070         2.459350
# 1          10227.689039     9.142971         226.292295         0.652502
# 2          17108.000000    32.000000        4823.000000        23.000000
# 3          65634.250000    69.250000       19960.000000        49.250000
#
#            Days_since_enroll  Award
# clusterId
# 0                4629.832656    1.0
# 1                3820.652105    0.0
# 2                7283.000000    1.0
# 3                2200.250000    1.0

# %%
print("silSilhouette_score {}".format(silhouette_score(air_norm,y_hc)))
# Out:
# silSilhouette_score 0.6428127612483802

# %% [markdown]
# # KMEANS

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
data_air=pd.read_excel("/content/sample_data/EastWestAirlines.xlsx", sheet_name="data")
data_air.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data_air2=data_air.drop('ID#',axis=1)
data_air2=data_air1.rename({'Award?':'Award'},axis=1)
data_air2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    clusterId
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0

# %%
#normalise the data
air_norm=norm_fun(data_air2)
air_norm.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0     0.011628           0.000000         0.000000           0.843742    0.0
# 1     0.023256           0.000000         0.000000           0.839884    0.0
# 2     0.046512           0.000000         0.000000           0.847842    0.0
# 3     0.011628           0.000000         0.000000           0.837955    0.0
# 4     0.302326           0.067398         0.075472           0.835905    1.0
#
#    clusterId
# 0   0.333333
# 1   0.333333
# 2   0.333333
# 3   0.333333
# ...

# %%
#lets do kmeans clustering and store the wcss value for elbow plot
wss=[]
for i in range(1,11):
  k_means=KMeans(n_clusters=i)
  k_means.fit(air_norm)
  wss.append(k_means.inertia_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
#elbow plot
plt.plot(range(1,11),wss)

# %%
# lets check for number of cluster = 3,4
k_means=KMeans(n_clusters=3)
k_means.fit(air_norm)
print("silSilhouette_score for n_cluster {}".format(silhouette_score(air_norm,k_means.labels_)))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# silSilhouette_score for n_cluster 0.4735419510648721

# %%
k_means=KMeans(n_clusters=4)
k_means.fit(air_norm)
y_hc=k_means.labels_
print("silSilhouette_score for n_cluster {}".format(silhouette_score(air_norm,k_means.labels_)))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# silSilhouette_score for n_cluster 0.4745982819358637

# %%
k_means=KMeans(n_clusters=5)
k_means.fit(air_norm)
print("silSilhouette_score for n_cluster {}".format(silhouette_score(air_norm,k_means.labels_)))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# silSilhouette_score for n_cluster 0.44280445234087357

# %%
# from above n_cluster=4 is having good result let go with that
data_air2['clusterId']=y_hc
data_air2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    clusterId
# 0          2
# 1          2
# 2          2
# 3          2
# 4          1

# %%
df_clust=data_air2.groupby('clusterId').mean()
df_clust
# Out:
#                  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterId
# 0          118032.061192   73.112721   3.576490   1.001610   1.022544
# 1          108317.387376  198.336634   3.915842   1.001238   1.025990
# 2           40747.617290   92.345809   1.092778   1.017923   1.004217
# 3           83529.153046  290.453195   1.156018   1.032689   1.008915
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterId
# 0          31282.666667    17.251208         225.352657         0.632850
# 1          45609.657178    20.201733         713.728960         2.142327
# 2           3335.152873     6.488666         226.599895         0.658935
# 3           8850.395245    10.476969        1030.112927         3.148588
#
#            Days_since_enroll  Award
# clusterId
# 0                4436.307568    0.0
# 1                4863.439356    1.0
# 2                3619.111755    0.0
# 3                4338.867756    1.0

# %% [markdown]
# # DBSCAN

# %%
data_air=pd.read_excel("/content/sample_data/EastWestAirlines.xlsx", sheet_name="data")
data_air.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data_air3=data_air.drop('ID#',axis=1)
data_air3=data_air1.rename({'Award?':'Award'},axis=1)
data_air3.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    clusterId
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0

# %%
data_air3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
#  11  clusterId          3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air_val=data_air3.values
air_val
# Out:
# array([[28143,     0,     1, ...,  7000,     0,     1],
#        [19244,     0,     1, ...,  6968,     0,     1],
#        [41354,     0,     1, ...,  7034,     0,     1],
#        ...,
#        [73597,     0,     3, ...,  1402,     1,     0],
#        [54899,     0,     1, ...,  1401,     0,     1],
#        [ 3016,     0,     1, ...,  1398,     0,     1]])

# %%
stscaler=StandardScaler().fit(air_val)
x=stscaler.transform(air_val)
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01,  7.50737966e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01,  7.50737966e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01,  7.50737966e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00, -1.29575224e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01,  7.50737966e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01,  7.50737966e-01]])

# %%
#lets start creating clustering with defining eps and min point
dbscan=DBSCAN(eps=2,min_samples=8)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2, min_samples=8)

# %%
data_air3['clusterId']=dbscan.labels_
data_air3.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    clusterId
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1

# %%
data_air3.groupby('clusterId').mean()
# Out:
#                  Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterId
# -1         233708.553488  1580.251163   2.730233   1.111628   1.227907
#  0          57829.535378    43.355010   1.697342   1.000000   1.000000
#  1          77324.045662    99.358447   2.643836   1.000000   1.000000
#  2          39218.500000     0.000000   1.000000   2.000000   1.000000
#  3          51096.000000     0.000000   1.000000   3.000000   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterId
# -1         49490.781395    25.939535        3574.990698        10.297674
#  0          9804.722699     8.918200         189.630266         0.557873
#  1         25618.030441    14.207763         459.470320         1.445967
#  2          9189.250000    13.500000         209.375000         0.812500
#  3         15561.666667    14.333333          44.444444         0.222222
#
#            Days_since_enroll     Award
# clusterId
# ...
